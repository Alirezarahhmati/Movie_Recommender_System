# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('movies_metadata.csv', encoding='cp1252')

# %%
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies.adult.value_counts()
# Out:
# False    45457
# True         9
# Name: adult, dtype: int64

# %%
movies[movies['adult'] == ' Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.']
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
movies.iloc[2953]
# Out:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                                   0
# genres                   [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# homepage                                  http://www.banzai-institute.com/
# id                                                                 11379.0
# imdb_id                                                          tt0086856
# original_language                                                       en
# original_title           The Adventures of Buckaroo Banzai Across the 8...
# overview                 Adventurer/surgeon/rock musician Buckaroo Banz...
# popularity                                                        7.778445
# poster_path                               /zaIvuZWPtmyQvsYMeLtox4vTlD2.jpg
# ...

# %%
movies.at[29503, 'adult']
# Out:
# False

# %%
movies[movies['adult'] ==' - Written by Ørnås']
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
movies['belongs_to_collection'].value_counts()
# Out:
# {'id': 415931, 'name': 'The Bowery Boys', 'poster_path': '/q6sA4bzMT9cK7EEmXYwt7PNrL5h.jpg', 'backdrop_path': '/foe3kuiJmg5AklhtD3skWbaTMf2.jpg'}                  29
# {'id': 421566, 'name': 'Totï¿½ï¿½ Collection', 'poster_path': '/4ayJsjC3djGwU9eCWUokdBWvdLC.jpg', 'backdrop_path': '/jaUuprubvAxXLAY5hUfrNjxccUh.j                 27
# {'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}                26
# {'id': 96887, 'name': 'Zatï¿½ï¿½ichi: The Blind Swordsman', 'poster_path': '/8Q31DAtmFJjhFTwQGXghBUCgWK2.jpg', 'backdrop_path': '/bY8gLImMR5Pr9PaG3ZpobfaAQ8N.j    26
# {'id': 37261, 'name': 'The Carry On Collection', 'poster_path': '/2P0HNrYgKDvirV8RCdT1rBSJdbJ.jpg', 'backdrop_path': '/38tF1LJN7ULeZAuAfP7beaPMfcl.jpg'}           25
# ...

# %%
for col in movies.columns:
    print(col)
    print(movies[col].value_counts())
# Out:
# adult
# False    45457
# True         9
# Name: adult, dtype: int64
# belongs_to_collection
# {'id': 415931, 'name': 'The Bowery Boys', 'poster_path': '/q6sA4bzMT9cK7EEmXYwt7PNrL5h.jpg', 'backdrop_path': '/foe3kuiJmg5AklhtD3skWbaTMf2.jpg'}                  29
# {'id': 421566, 'name': 'Totï¿½ï¿½ Collection', 'poster_path': '/4ayJsjC3djGwU9eCWUokdBWvdLC.jpg', 'backdrop_path': '/jaUuprubvAxXLAY5hUfrNjxccUh.j                 27
# {'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}                26
# {'id': 96887, 'name': 'Zatï¿½ï¿½ichi: The Blind Swordsman', 'poster_path': '/8Q31DAtmFJjhFTwQGXghBUCgWK2.jpg', 'backdrop_path': '/bY8gLImMR5Pr9PaG3ZpobfaAQ8N.j    26
# {'id': 37261, 'name': 'The Carry On Collection', 'poster_path': '/2P0HNrYgKDvirV8RCdT1rBSJdbJ.jpg', 'backdrop_path': '/38tF1LJN7ULeZAuAfP7beaPMfcl.jpg'}           25
# ...

# %%
movies.describe()
# Out:
#              budget             id    popularity       revenue       runtime  \
# count  4.546600e+04   45463.000000  45463.000000  4.546000e+04  45206.000000
# mean   4.224300e+06  108359.918813      2.921378  1.120935e+07     94.127572
# std    1.742359e+07  112460.749278      6.005234  6.433225e+07     38.406803
# min    0.000000e+00       2.000000      0.000000  0.000000e+00      0.000000
# 25%    0.000000e+00   26449.500000      0.385945  0.000000e+00     85.000000
# 50%    0.000000e+00   60003.000000      1.127757  0.000000e+00     95.000000
# 75%    0.000000e+00  157328.000000      3.678588  0.000000e+00    107.000000
# max    3.800000e+08  469172.000000    547.488298  2.787965e+09   1256.000000
#
#        vote_average    vote_count
# count  45463.000000  45463.000000
# mean       5.618217    109.890856
# std        1.924174    491.294816
# min        0.000000      0.000000
# 25%        5.000000      3.000000
# 50%        6.000000     10.000000
# ...

# %%
movies.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40975
# budget                       0
# genres                       3
# homepage                 37687
# id                           3
# imdb_id                     19
# original_language           13
# original_title               0
# overview                   954
# popularity                   3
# poster_path                387
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    260
# spoken_languages             3
# status                      84
# tagline                  25054
# title                        4
# video                        5
# vote_average                 3
# vote_count                   3
# dtype: int64
